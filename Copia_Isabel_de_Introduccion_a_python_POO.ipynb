# %% [markdown]
# **Ejercicio 0.1: Variables y Tipos de Datos Básicos**
#
# Reto para el alumno: Crea las variables que representen el perfil de un usuario del sistema y calcula su año aproximado de nacimiento.

# %%
# 1. Asigna los valores correctos a las variables
nombre = "Isabel"          # Texto (str)
apellido ="Ortiz Mendez"
colorfav = "azul "
pelicula = "robot salvaje"
fecha_nacimiento = "15 de enero"

edad = 20                  # Entero (int)
estatus_activo = True      # Booleano (bool)

# 2. Operación matemática básica
# Asumiendo que el año actual es 2026:
anio_actual = 2026
anio_nacimiento = anio_actual - edad

# Imprimir resultados usando f-strings (crucial para APIs)
print(f"Usuario: {nombre}")
print(f"apellido: {apellido}")
print(f"color favorito: {colorfav}")
print(f"pelicula favorita: {pelicula}")
print(f"tu cumpleaños es: {fecha_nacimiento}")
print(f"Naciste en: {anio_nacimiento}\nEl mejor año")
# Out:
# Usuario: Isabel
# apellido: Ortiz Mendez
# color favorito: Rosa pastel
# pelicula favorita: robot salvaje
# tu cumpleaños es: 15 de enero
# Naciste en: 2006
# El mejor año

# %% [markdown]
# **Ejercicio 0.2: Condicionales y Bucles (Control de Flujo)**
#
# Reto para el alumno: Simula un sistema que procesa una lista de solicitudes de inscripción. Si el alumno es menor de edad, el sistema debe rechazarlo; si es mayor, lo aprueba.

# %%
# Lista de edades de alumnos que quieren ingresar a la universidad
edades_alumnos = [18, 5, 22, 15, 30, 25, 23, 12, 19, 28, 35, 65, 15]

print("--- procesando ---")


# Bucle para recorrer la lista
for edad in edades_alumnos:
    # Condicional para verificar la mayoría de edad (18 años)
    if edad >= 20:
        print(f"EDAD {edad}: Solicitud APROBADA.")
    else:
        print(f"Edad {edad}: Solicitud RECHAZADA (Menor de edad).")
# Out:
# --- procesando ---
# Edad 18: Solicitud RECHAZADA (Menor de edad).
# Edad 5: Solicitud RECHAZADA (Menor de edad).
# EDAD 22: Solicitud APROBADA.
# Edad 15: Solicitud RECHAZADA (Menor de edad).
# EDAD 30: Solicitud APROBADA.
# EDAD 25: Solicitud APROBADA.
# EDAD 23: Solicitud APROBADA.
# Edad 12: Solicitud RECHAZADA (Menor de edad).
# Edad 19: Solicitud RECHAZADA (Menor de edad).
# EDAD 28: Solicitud APROBADA.
# EDAD 35: Solicitud APROBADA.
# EDAD 65: Solicitud APROBADA.
# Edad 15: Solicitud RECHAZADA (Menor de edad).

# %% [markdown]
# **Ejercicio 0.3: Funciones y Parámetros**
#
#   Reto para el alumno: Crea una función que calcule el precio de un producto aplicando el IVA (16%). Debe recibir el precio base y retornar el total.

# %%
# Definición de la función con parámetros
def calcular_precio_con_iva(precio_base: float) -> float:
    iva = 0.08
    total = precio_base + (precio_base * iva)
    return total

# Pruebas de la función
producto_A = 120.0
producto_B = 499.99
Producto_C = 100.0
producto_D = 80.0
producto_E = 25.5
producto_F = 60.3
producto_G = 55.4
producto_H = 91.5
producto_I = 12.8
producto_J= 36.8
producto_K = 85.6
producto_L = 20.7


print(f"Total Producto A con IVA: ${calcular_precio_con_iva(producto_A):.2f}")
print(f"Total Producto B con IVA: ${calcular_precio_con_iva(producto_B):.2f}")
print(f"total producto C con IVA: ${calcular_precio_con_iva (Producto_C):.2f}")
print(f"Total producto D con IVA: ${calcular_precio_con_iva (producto_D):.2f}")
print(f"Total producto E con iva: ${calcular_precio_con_iva(producto_E):.2f}")
print(f"Total producto F con iva: ${calcular_precio_con_iva(producto_F):.2f}")
print(f"Total prodcuto G con iva: ${calcular_precio_con_iva(producto_G):.2f}")
print(f"Total prodcuto H con iva: ${calcular_precio_con_iva(producto_H):.2f}")
print(f"Total prodcuto I con iva: ${calcular_precio_con_iva(producto_I):.2f}")
print(f"Total prodcuto J con iva: ${calcular_precio_con_iva(producto_J):.2f}")
print(f"Total producto K con iva: ${calcular_precio_con_iva(producto_K):.2f}")
print(f"Total producto L con iva: ${calcular_precio_con_iva(producto_L):.2f}")
# Out:
# Total Producto A con IVA: $129.60
# Total Producto B con IVA: $539.99
# total producto C con IVA: $108.00
# Total producto D con IVA: $86.40
# Total producto E con iva: $27.54
# Total producto F con iva: $65.12
# Total prodcuto G con iva: $59.83
# Total prodcuto H con iva: $98.82
# Total prodcuto I con iva: $13.82
# Total prodcuto J con iva: $39.74
# Total producto K con iva: $92.45
# Total producto L con iva: $22.36

# %% [markdown]
# **Ejercicio 0.4: Introducción a Objetos (El estilo Pydantic/FastAPI)**

# %%
from pydantic import BaseModel

# Definición de la Clase (Molde del Objeto)
class Alumno(BaseModel):
    id: int
    nombre: str
    carrera: str
    promedio: float

# Crear una instancia del objeto (Instanciación)
alumno_juan = Alumno(id=1, nombre="Juan Pérez", carrera="Sistemas", promedio=91.5)

# Acceder a sus atributos utilizando la notación de punto (.)
print(f"Se ha registrado a {alumno_juan.nombre} de la carrera de {alumno_juan.carrera}.")

# ¿Qué pasa si intentamos convertirlo a un formato de intercambio de datos (JSON/Diccionario)?
print("\nObjeto convertido a diccionario listo para una API:")
print(alumno_juan.model_dump())
# Out:
# Se ha registrado a Juan Pérez de la carrera de Sistemas.
#
# Objeto convertido a diccionario listo para una API:
# {'id': 1, 'nombre': 'Juan Pérez', 'carrera': 'Sistemas', 'promedio': 91.5}

# %% [markdown]
# Configuración, Tipos de Datos y Consola

# %%
# 1.1 Manejo de Módulos (Equivalente a Using/Namespaces)
import sys
import datetime

# 1.4 Entradas y Salidas a Consola
print("--- Inicializando Sistema de Ingesta ---")

# 1.2 Tipos de Datos (Tipado dinámico)
pipeline_name = "ETL_Tijuana_Norte"
active_nodes = 15
cpu_usage = 45.5
is_pipeline_active = True

# Usamos f-strings para inyectar variables fácilmente en el texto
print(f"Pipeline: {pipeline_name} | Activo: {is_pipeline_active}")
print(f"Nodos: {active_nodes} | CPU: {cpu_usage}%")

# Para solicitar entradas en Colab:
# limite = input("Ingresa el límite de carga: ")
# Out:
# --- Inicializando Sistema de Ingesta ---
# Pipeline: ETL_Tijuana_Norte | Activo: True
# Nodos: 15 | CPU: 45.5%

# %% [markdown]
# Variables, Conversiones y Operaciones

# %%
# 1.2 Variables y Conversiones de Tipos
input_registros = "2500"
registros_totales = int(input_registros) # Conversión explícita de texto a entero
costo_por_mega = 1.75

# 1.3 Operadores y Operaciones Matemáticas
costo_total = registros_totales * costo_por_mega
costo_con_impuesto = costo_total + (costo_total * 0.16)

costo_redondeado = int(costo_con_impuesto) # Casteo para remover decimales

print("Cálculo finalizado.")
print(f"Costo exacto: ${costo_con_impuesto} | Costo redondeado: ${costo_redondeado}")
# Out:
# Cálculo finalizado.
# Costo exacto: $5075.0 | Costo redondeado: $5075

# %% [markdown]
# **La analogía de un Restaurante:**
#
#   El Cliente (Navegador/Postman): El comensal que se sienta a la mesa.
#
#   Los Métodos HTTP: La acción que el cliente quiere realizar (Ver el menú, pedir comida, cambiar su orden o cancelar un plato).
#
#   FastAPI: El mesero que toma la orden, la lleva a la cocina (las funciones de Python) y regresa con un resultado y un estado (si el plato está listo o si se acabó el ingrediente).

# %% [markdown]
# **1. Los Métodos HTTP (Verbos)**
#
# Para gestionar un recurso (por ejemplo, los datos de un Alumno), usamos cuatro verbos principales:
#
# *    GET (Leer): El cliente solicita información. No modifica nada en el servidor. (Equivale a pedir ver la carta del restaurante).
#
#  *   POST (Crear): El cliente envía datos nuevos para que el servidor los guarde. (Equivale a ordenar un plato nuevo).
#
#  *   PUT (Actualizar): El cliente envía datos para modificar o reemplazar un recurso existente. (Equivale a cambiar tu plato de sopa por uno de carne).
#
# *    DELETE (Borrar): El cliente solicita eliminar un recurso. (Equivale a cancelar un pedido antes de que lo cocinen).

# %% [markdown]
# **2. Los Códigos de Estado (Status Codes)**
#
# El servidor siempre debe responder con un número de tres dígitos que le indica al cliente qué pasó con su petición. Se dividen en familias fáciles de recordar:
#
#  *   Familia 200 (Éxito): "¡Todo salió bien!"
#
#       * 200 OK: La petición fue exitosa (común en GET y PUT).
#       * 201 Created: El recurso se creó con éxito (común en POST).
#
#  *   Familia 300 (Redirección): "El recurso se movió de lugar".
#
#       * 301 Moved Permanently: La página o API ahora está en otra dirección web.
#
#  *   Familia 400 (Errores del Cliente): "Es culpa del usuario".
#
#       * 400 Bad Request: El cliente mandó datos mal estructurados.
#
#       * 401 Unauthorized: El usuario no ha iniciado sesión o no tiene permiso.
#
#       * 404 Not Found: Lo que el cliente busca no existe (el clásico error web).
#
#  *   Familia 500 (Errores del Servidor): "Es culpa del programador / sistema".
#
#       * 500 Internal Server Error: El código de Python falló (hubo un crash o bug) y el servidor no supo qué hacer.

# %% [markdown]
# **Un CRUD Completo con Respuestas Correctas**
#
# Tus alumnos pueden copiar y ejecutar este código directamente en Colab. Simularemos una base de datos usando una lista de Python para que vean cómo interactúan las clases (POO), las funciones y los métodos HTTP.

# %% [markdown]
# **Validacion de endpoint de FastAPI**
